# %% [markdown]
# # Candidate Generation (Blocking) Benchmark
#
# This notebook analyzes the performance of our blocking strategies based on the metrics produced in `blocking_results.csv`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

results_path = '../experiments/results/blocking_results.csv'
if os.path.exists(results_path):
    df = pd.read_csv(results_path)
    display(df)
else:
    print('No blocking results found.')
